# %%
# Dependencies
#import libraries

import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import weather_api_key
from citipy import citipy
import numpy as np

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Read csv file provided
output_data = "output_data/cities.csv"

# Define latitude and Longitute, I took the values from the world map lat and long
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Define empty lists for cities and long and lat

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 621

# %%
cities
# Out:
# ['sulangan',
#  'nelson bay',
#  'mazamari',
#  'mataura',
#  'teya',
#  'rosarito',
#  'yulara',
#  'tumannyy',
#  'albany',
#  'provideniya',
#  'lewiston',
#  'tual',
#  'diego de almagro',
#  'tazmalt',
#  'taolanaro',
#  'praia',
#  'bambous virieux',
#  'rikitea',
#  'kaitangata',
#  'ushuaia',
#  'torbay',
#  'bengkulu',
#  'rudnogorsk',
#  'mandera',
#  'palabuhanratu',
#  'hualmay',
#  'cape town',
#  'shubarshi',
#  'barrow',
#  'ostrovnoy',
#  'the valley',
#  'pocosol',
#  'atuona',
#  'avarua',
#  'mayahi',
#  'touros',
#  'lamar',
#  'ishigaki',
#  'la ronge',
#  'labuhan',
#  'abulug',
#  'ribeira grande',
#  'thompson',
#  'esperance',
#  'shangzhi',
#  'cabo san lucas',
#  'tasiilaq',
#  'qaanaaq',
#  'kapaa',
#  'luderitz',
#  'leon',
#  'linhares',
#  'punta arenas',
#  'puerto ayora',
#  'guider',
#  'norashen',
#  'bluff',
#  'norman wells',
#  'georgetown',
#  'saskylakh',
#  'jamestown',
#  'busselton',
#  'kamenskiy',
#  'grand river south east',
#  'pimentel',
#  'cuenca',
#  'honiara',
#  'tautira',
#  'hofn',
#  'saint-francois',
#  'victoria',
#  'batagay-alyta',
#  'cartagena del chaira',
#  'codrington',
#  'bredasdorp',
#  'vila franca do campo',
#  'sabha',
#  'illoqqortoormiut',
#  'kelo',
#  'pierre',
#  'souillac',
#  'harper',
#  'samusu',
#  'husainabad',
#  'muravlenko',
#  'beba',
#  'port elizabeth',
#  'atasu',
#  'portland',
#  'new norfolk',
#  'dzhebariki-khaya',
#  'mys shmidta',
#  'mullaitivu',
#  'khatanga',
#  'batyrevo',
#  'lorengau',
#  'aljezur',
#  'pachino',
#  'port alfred',
#  'plettenberg bay',
#  'cidreira',
#  'hermanus',
#  'ancud',
#  'kysyl-syr',
#  'longyearbyen',
#  'laguna',
#  'muroto',
#  'mahebourg',
#  'kirkland lake',
#  'alice springs',
#  'sao filipe',
#  'kruisfontein',
#  'yellowknife',
#  'kavieng',
#  'umm nuwarah',
#  'vao',
#  'clyde river',
#  'dikson',
#  'bandar-e torkaman',
#  'fairlie',
#  'acapulco',
#  'saint-philippe',
#  'tuatapere',
#  'hoopstad',
#  'ubinskoye',
#  'karauzyak',
#  'andros',
#  'hilo',
#  'vila velha',
#  'coos bay',
#  'hamilton',
#  'kwinana',
#  'cizre',
#  'vaini',
#  'kholtoson',
#  'burica',
#  'iskateley',
#  'geraldton',
#  'leshukonskoye',
#  'port lincoln',
#  'vanavara',
#  'kodiak',
#  'bambanglipuro',
#  'bubaque',
#  'nouadhibou',
#  'lagoa',
#  'belushya guba',
#  'ponta do sol',
#  'east london',
#  'krasnoselkup',
#  'hithadhoo',
#  'buala',
#  'airai',
#  'mayo',
#  'lebu',
#  'nizhneyansk',
#  'tura',
#  'wick',
#  'kerema',
#  'goderich',
#  'pangnirtung',
#  'dalvik',
#  'camana',
#  'mao',
#  'salalah',
#  'hobart',
#  'kamina',
#  'barentu',
#  'oriximina',
#  'nikolskoye',
#  'labuan',
#  'rudbar',
#  'awbari',
#  'kasongo-lunda',
#  'kuching',
#  'nokaneng',
#  'narsaq',
#  'tuktoyaktuk',
#  'sitka',
#  'qasigiannguit',
#  'barentsburg',
#  'sebu',
#  'asau',
#  'gimli',
#  'hovd',
#  'chokurdakh',
#  'preobrazheniye',
#  'bolshoy kamen',
#  'cam ranh',
#  'hasaki',
#  'bojnurd',
#  'aquiraz',
#  'phalombe',
#  'lazurne',
#  'muros',
#  'talnakh',
#  'vicksburg',
#  'college',
#  'kurumkan',
#  'kamenka',
#  'te anau',
#  'mar del plata',
#  'pacific grove',
#  'kota belud',
#  'mayumba',
#  'saint-pierre',
#  'la roche-sur-yon',
#  'sibolga',
#  'grand centre',
#  'mayya',
#  'madang',
#  'sile',
#  'kamenskoye',
#  'mehamn',
#  'pevek',
#  'banyo',
#  'quelimane',
#  'itapecerica',
#  'lata',
#  'rio gallegos',
#  'constitucion',
#  'quang ngai',
#  'homer',
#  'mishan',
#  'omboue',
#  'aksu',
#  'kuytun',
#  'tabuk',
#  'kontagora',
#  'pidhorodne',
#  'butaritari',
#  'ilhabela',
#  'sorland',
#  'cockburn town',
#  'borovoy',
#  'aripuana',
#  'miraflores',
#  'bilma',
#  'port angeles',
#  'klyuchi',
#  'gharb',
#  'iqaluit',
#  'marawi',
#  'moravske budejovice',
#  'carnarvon',
#  'manakara',
#  'amderma',
#  'mareeba',
#  'severo-kurilsk',
#  'louisbourg',
#  'oistins',
#  'arraial do cabo',
#  'pasighat',
#  'huancavelica',
#  'turan',
#  'lieksa',
#  'anadyr',
#  'grand gaube',
#  'tumpat',
#  'chimbote',
#  'kulpahar',
#  'kirakira',
#  'chagda',
#  'broome',
#  'adrar',
#  'lang suan',
#  'yerbogachen',
#  'alofi',
#  'fayaoue',
#  'boddam',
#  'tres arroyos',
#  'tsihombe',
#  'zolochiv',
#  'zinder',
#  'opuwo',
#  'strenci',
#  'ventspils',
#  'sandnessjoen',
#  'usinsk',
#  'cherskiy',
#  'utete',
#  'inhambane',
#  'severo-yeniseyskiy',
#  'margate',
#  'ust-nera',
#  'aktash',
#  'ormstown',
#  'gaoua',
#  'castro',
#  'iquitos',
#  'almaznyy',
#  'saint george',
#  'totma',
#  'ilulissat',
#  'nizhnyaya tavda',
#  'hami',
#  'praia da vitoria',
#  'sakakah',
#  'russell',
#  'tiksi',
#  'mpanda',
#  'kitimat',
#  'centralia',
#  'broken hill',
#  'roebourne',
#  'sandusky',
#  'sinnamary',
#  'kaeo',
#  'xai-xai',
#  'vanimo',
#  'korostyshiv',
#  'marsaxlokk',
#  'husavik',
#  'waingapu',
#  'leningradskiy',
#  'chuy',
#  'menomonie',
#  'saldanha',
#  'viligili',
#  'attawapiskat',
#  'pochutla',
#  'mae sai',
#  'natal',
#  'briancon',
#  'mattru',
#  'klaksvik',
#  'aklavik',
#  'rassvet',
#  'vaitape',
#  'saint-andre-avellin',
#  'zabid',
#  'christchurch',
#  'eenhana',
#  'sinazongwe',
#  'manicore',
#  'meulaboh',
#  'mount isa',
#  'itarema',
#  'katsuura',
#  'yambio',
#  'malaryta',
#  'pudozh',
#  'calbuco',
#  'tibu',
#  'cervo',
#  'fos-sur-mer',
#  'imeni karla libknekhta',
#  'paslek',
#  'bethel',
#  'vila',
#  'periyanegamam',
#  'ibra',
#  'nanortalik',
#  'savannakhet',
#  'skibbereen',
#  'mbuji-mayi',
#  'mogadishu',
#  'hobyo',
#  'zarand',
#  'upernavik',
#  'sagarejo',
#  'komsomolskiy',
#  'evensk',
#  'berbera',
#  'thaba-tseka',
#  'ciras',
#  'najran',
#  'lumby',
#  'san patricio',
#  'cozumel',
#  'nhulunbuy',
#  'cayenne',
#  'ruteng',
#  'daru',
#  'fevralsk',
#  'vaitupu',
#  'saucillo',
#  'dingle',
#  'san rafael',
#  'sibu',
#  'pauini',
#  'tingi',
#  'henties bay',
#  'maniitsoq',
#  'karla',
#  'tateyama',
#  'asosa',
#  'maceo',
#  'marzuq',
#  'hambantota',
#  'santa cruz de la palma',
#  'tecoanapa',
#  'helong',
#  'sovetskiy',
#  'livingstone',
#  'chaozhou',
#  'san borja',
#  'faya',
#  'san felipe',
#  'northam',
#  'tabiauea',
#  'puerto madryn',
#  'dzerzhinsk',
#  'yaan',
#  'san cristobal',
#  'igarka',
#  'andenes',
#  'belaya gora',
#  'porbandar',
#  'storforshei',
#  'casma',
#  'jinhua',
#  'lastoursville',
#  'jalingo',
#  'jaciara',
#  'lavrentiya',
#  'hurghada',
#  'asahikawa',
#  'grindavik',
#  'makakilo city',
#  'izyaslav',
#  'maghama',
#  'boulder',
#  'lagos',
#  'warqla',
#  'port blair',
#  'gamba',
#  'ouesso',
#  'otradnoye',
#  'belmopan',
#  'huilong',
#  'hay river',
#  'urulga',
#  'necochea',
#  'along',
#  'misratah',
#  'espanola',
#  'santa cruz cabralia',
#  'victor harbor',
#  'gravdal',
#  'gornopravdinsk',
#  'palmer',
#  'puerto suarez',
#  'sentyabrskiy',
#  'kahului',
#  'kudat',
#  'hermiston',
#  'tegal',
#  'aldine',
#  'mandalgovi',
#  'bairiki',
#  'karpathos',
#  'umzimvubu',
#  'teshie',
#  'gobabis',
#  'umm lajj',
#  'monki',
#  'pyapon',
#  'santa fe',
#  'tessalit',
#  'aflu',
#  'cleveland',
#  'kaithal',
#  'bathsheba',
#  'ruatoria',
#  'kieta',
#  'boende',
#  'fresno',
#  'safaga',
#  'zhigalovo',
#  'banjar',
#  'berlevag',
#  'semey',
#  'san bartolome jocotenango',
#  'nuevo progreso',
#  'kalaleh',
#  'kavaratti',
#  'paris',
#  'niltepec',
#  'charleville',
#  'campos belos',
#  'monterey',
#  'toyooka',
#  'santa cruz',
#  'pisco',
#  'bilibino',
#  'egvekinot',
#  'kem',
#  'rabo de peixe',
#  'turukhansk',
#  'svetlogorsk',
#  'meyungs',
#  'vardo',
#  'pangkalanbuun',
#  'damietta',
#  'ahipara',
#  'lahij',
#  'salgado',
#  'soyo',
#  'derzhavinsk',
#  'eydhafushi',
#  'carutapera',
#  'shubarkuduk',
#  'calama',
#  'ussuriysk',
#  'palana',
#  'massakory',
#  'eusebio ayala',
#  'lufkin',
#  'bababe',
#  'vetluzhskiy',
#  'bafq',
#  'mount gambier',
#  'haines junction',
#  'alamos',
#  'weligama',
#  'isangel',
#  'churapcha',
#  'ondorhaan',
#  'sao joao da barra',
#  'altay',
#  'melilla',
#  'te kauwhata',
#  'mitrofanovka',
#  'sambava',
#  'kankan',
#  'moose factory',
#  'mamlyutka',
#  'la palma',
#  'marcona',
#  'ixtapa',
#  'villamontes',
#  'ambon',
#  'dubbo',
#  'seymchan',
#  'ulaangom',
#  'zaraza',
#  'los llanos de aridane',
#  'port moresby',
#  'vostok',
#  'safranbolu',
#  'mumford',
#  'inskoy',
#  'fiumicino',
#  'tukrah',
#  'okhotsk',
#  'zhuhai',
#  'goundam',
#  'alta floresta',
#  'lompoc',
#  'kandrian',
#  'kaili',
#  'kaputa',
#  'guerrero negro',
#  'konispol',
#  'espita',
#  'sorvag',
#  'tuggurt',
#  'faanui',
#  'saleaula',
#  'san juan',
#  'acajutla',
#  'deh rawud',
#  'yumbe',
#  'koslan',
#  'lasa',
#  'ca mau',
#  'barranquilla',
#  'sola',
#  'nome',
#  'coihaique',
#  'mapastepec',
#  'aleksandrov gay',
#  'havre',
#  'lamu',
#  'kushmurun',
#  'poya',
#  'kupang',
#  'pedernales',
#  'kokoda',
#  'zigong',
#  'lake havasu city',
#  'zomin',
#  'san jeronimo',
#  'jiddah',
#  'zaanstad',
#  'shimoda',
#  'samarai',
#  'abu zabad',
#  'umuahia',
#  'khargone',
#  'kiunga',
#  'aleksandrovka',
#  'auki',
#  'roma',
#  'cordoba',
#  'morondava',
#  'cah ab',
#  'babati',
#  'kiruna',
#  'grove city',
#  'caravelas',
#  'suntar',
#  'hihifo',
#  'verkhoyansk',
#  'florencia',
#  'monze',
#  'kozhva',
#  'empalme',
#  'talaya',
#  'comodoro rivadavia',
#  'hlobyne',
#  'karlskrona',
#  'llanes',
#  'naze',
#  'la seyne-sur-mer',
#  'shache',
#  'yalchiki',
#  'itamarandiba',
#  'yarmouth',
#  'burley']

# %%
#retrieve news cities, create empty lists

new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temperature = []
lat = []
lng = []
wind_speedy = []

# %%
cloudiness
# Out:
# []

# %%
# Build partial query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#Testing url
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?'

# %%
#testing weather_api_key

weather_api_key
# Out:
# '831d4685f8ee37d49664dc84d403437e'

# %%
#looping into the cities
#using enumerate to get the index of the list

for i, city in enumerate(cities):
               
    try:
        print(i,city)
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temperature.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speedy.append(response['wind']['speed'])
        lng.append(response['coord']['lon'])
        new_cities.append(city)
            
    except Exception as e: #e however problem has in the list and ir tells you what the error is
        print(e)    

new_cities
# Out:
# 0 sulangan
# 1 nelson bay
# 2 mazamari
# 3 mataura
# 4 teya
# 5 rosarito
# 6 yulara
# 7 tumannyy
# 'coord'
# 8 albany
# 9 provideniya
# 10 lewiston
# 11 tual
# 12 diego de almagro
# 13 tazmalt
# 14 taolanaro
# 'coord'
# 15 praia
# 16 bambous virieux
# 17 rikitea
# 18 kaitangata
# 19 ushuaia
# 20 torbay
# 21 bengkulu
# 22 rudnogorsk
# 23 mandera
# 24 palabuhanratu
# 'coord'
# 25 hualmay
# 26 cape town
# 27 shubarshi
# 28 barrow
# 29 ostrovnoy
# 30 the valley
# 31 pocosol
# 32 atuona
# 33 avarua
# 34 mayahi
# 35 touros
# 36 lamar
# 37 ishigaki
# 38 la ronge
# 39 labuhan
# 40 abulug
# 41 ribeira grande
# 42 thompson
# 43 esperance
# 44 shangzhi
# 45 cabo san lucas
# 46 tasiilaq
# 47 qaanaaq
# 48 kapaa
# 49 luderitz
# 50 leon
# 51 linhares
# 52 punta arenas
# 53 puerto ayora
# 54 guider
# 55 norashen
# 56 bluff
# 57 norman wells
# 58 georgetown
# 59 saskylakh
# 60 jamestown
# 61 busselton
# 62 kamenskiy
# 63 grand river south east
# 'coord'
# 64 pimentel
# 65 cuenca
# 66 honiara
# 67 tautira
# 68 hofn
# 69 saint-francois
# 70 victoria
# 71 batagay-alyta
# 72 cartagena del chaira
# 73 codrington
# 74 bredasdorp
# 75 vila franca do campo
# 76 sabha
# 77 illoqqortoormiut
# 'coord'
# 78 kelo
# 79 pierre
# 80 souillac
# 81 harper
# 82 samusu
# 'coord'
# 83 husainabad
# 84 muravlenko
# 85 beba
# 86 port elizabeth
# 87 atasu
# 88 portland
# 89 new norfolk
# 90 dzhebariki-khaya
# 91 mys shmidta
# 'coord'
# 92 mullaitivu
# 'coord'
# 93 khatanga
# 94 batyrevo
# 95 lorengau
# 96 aljezur
# 97 pachino
# 98 port alfred
# 99 plettenberg bay
# 100 cidreira
# 101 hermanus
# 102 ancud
# 103 kysyl-syr
# 104 longyearbyen
# 105 laguna
# 106 muroto
# 107 mahebourg
# 108 kirkland lake
# 109 alice springs
# 110 sao filipe
# 111 kruisfontein
# 112 yellowknife
# 113 kavieng
# 114 umm nuwarah
# 'coord'
# 115 vao
# 116 clyde river
# 117 dikson
# 118 bandar-e torkaman
# 'coord'
# 119 fairlie
# 120 acapulco
# 121 saint-philippe
# 122 tuatapere
# 123 hoopstad
# 124 ubinskoye
# 125 karauzyak
# 'coord'
# 126 andros
# 127 hilo
# 128 vila velha
# 129 coos bay
# 130 hamilton
# 131 kwinana
# 132 cizre
# 133 vaini
# 134 kholtoson
# 135 burica
# 'coord'
# 136 iskateley
# 137 geraldton
# 138 leshukonskoye
# 139 port lincoln
# 140 vanavara
# 141 kodiak
# 142 bambanglipuro
# 143 bubaque
# 144 nouadhibou
# 145 lagoa
# 146 belushya guba
# 'coord'
# 147 ponta do sol
# 148 east london
# 149 krasnoselkup
# 150 hithadhoo
# 151 buala
# 152 airai
# 153 mayo
# 154 lebu
# 155 nizhneyansk
# 'coord'
# 156 tura
# 157 wick
# 158 kerema
# 159 goderich
# 160 pangnirtung
# 161 dalvik
# 162 camana
# 163 mao
# 164 salalah
# 489 turukhansk
# 490 svetlogorsk
# 491 meyungs
# 'coord'
# 492 vardo
# 493 pangkalanbuun
# 494 damietta
# 495 ahipara
# 496 lahij
# 497 salgado
# 498 soyo
# 499 derzhavinsk
# 500 eydhafushi
# 501 carutapera
# 502 shubarkuduk
# 503 calama
# 504 ussuriysk
# 505 palana
# 506 massakory
# 507 eusebio ayala
# 508 lufkin
# 509 bababe
# 'coord'
# 510 vetluzhskiy
# 511 bafq
# 512 mount gambier
# 513 haines junction
# 514 alamos
# 515 weligama
# 516 isangel
# 517 churapcha
# 518 ondorhaan
# 'coord'
# 519 sao joao da barra
# 520 altay
# 521 melilla
# 522 te kauwhata
# 523 mitrofanovka
# 524 sambava
# 525 kankan
# 526 moose factory
# 527 mamlyutka
# 528 la palma
# 529 marcona
# 'coord'
# 530 ixtapa
# 531 villamontes
# 532 ambon
# 533 dubbo
# 534 seymchan
# 535 ulaangom
# 536 zaraza
# 537 los llanos de aridane
# 538 port moresby
# 539 vostok
# 540 safranbolu
# 541 mumford
# 542 inskoy
# 543 fiumicino
# 544 tukrah
# 545 okhotsk
# 546 zhuhai
# 547 goundam
# 548 alta floresta
# 549 lompoc
# 550 kandrian
# 551 kaili
# 552 kaputa
# 553 guerrero negro
# 554 konispol
# 555 espita
# 556 sorvag
# 'coord'
# 557 tuggurt
# 'coord'
# 558 faanui
# 559 saleaula
# 'coord'
# 560 san juan
# 561 acajutla
# 562 deh rawud
# 'coord'
# 563 yumbe
# 564 koslan
# 565 lasa
# 566 ca mau
# 567 barranquilla
# 568 sola
# 569 nome
# 570 coihaique
# 571 mapastepec
# 572 aleksandrov gay
# 573 havre
# 574 lamu
# 575 kushmurun
# 576 poya
# 577 kupang
# 578 pedernales
# 579 kokoda
# 580 zigong
# 581 lake havasu city
# 582 zomin
# 583 san jeronimo
# 584 jiddah
# 'coord'
# 585 zaanstad
# 586 shimoda
# 587 samarai
# 588 abu zabad
# 589 umuahia
# 590 khargone
# 591 kiunga
# 592 aleksandrovka
# 593 auki
# 594 roma
# 595 cordoba
# 596 morondava
# 597 cah ab
# 'coord'
# 598 babati
# 599 kiruna
# 600 grove city
# 601 caravelas
# 602 suntar
# 603 hihifo
# 'coord'
# 604 verkhoyansk
# 605 florencia
# 606 monze
# 607 kozhva
# 608 empalme
# 609 talaya
# 610 comodoro rivadavia
# 611 hlobyne
# 612 karlskrona
# 613 llanes
# 614 naze
# 615 la seyne-sur-mer
# 616 shache
# 617 yalchiki
# 'coord'
# 618 itamarandiba
# 619 yarmouth
# 620 burley
# ['sulangan',
#  'nelson bay',
#  'mazamari',
#  'mataura',
#  'teya',
#  'rosarito',
#  'yulara',
#  'albany',
#  'provideniya',
#  'lewiston',
#  'tual',
#  'diego de almagro',
#  'tazmalt',
#  'praia',
#  'bambous virieux',
#  'rikitea',
#  'kaitangata',
#  'ushuaia',
#  'torbay',
#  'bengkulu',
#  'rudnogorsk',
#  'mandera',
#  'hualmay',
#  'cape town',
#  'shubarshi',
#  'barrow',
#  'ostrovnoy',
#  'the valley',
#  'pocosol',
#  'atuona',
#  'avarua',
#  'mayahi',
#  'touros',
#  'lamar',
#  'ishigaki',
#  'la ronge',
#  'labuhan',
#  'abulug',
#  'ribeira grande',
#  'thompson',
#  'esperance',
#  'shangzhi',
#  'cabo san lucas',
#  'tasiilaq',
#  'qaanaaq',
#  'kapaa',
#  'luderitz',
#  'leon',
#  'linhares',
#  'punta arenas',
#  'puerto ayora',
#  'guider',
#  'norashen',
#  'bluff',
#  'norman wells',
#  'georgetown',
#  'saskylakh',
#  'jamestown',
#  'busselton',
#  'kamenskiy',
#  'pimentel',
#  'cuenca',
#  'honiara',
#  'tautira',
#  'hofn',
#  'saint-francois',
#  'victoria',
#  'batagay-alyta',
#  'cartagena del chaira',
#  'codrington',
#  'bredasdorp',
#  'vila franca do campo',
#  'sabha',
#  'kelo',
#  'pierre',
#  'souillac',
#  'harper',
#  'husainabad',
#  'muravlenko',
#  'beba',
#  'port elizabeth',
#  'atasu',
#  'portland',
#  'new norfolk',
#  'dzhebariki-khaya',
#  'khatanga',
#  'batyrevo',
#  'lorengau',
#  'aljezur',
#  'pachino',
#  'port alfred',
#  'plettenberg bay',
#  'cidreira',
#  'hermanus',
#  'ancud',
#  'kysyl-syr',
#  'longyearbyen',
#  'laguna',
#  'muroto',
#  'mahebourg',
#  'kirkland lake',
#  'alice springs',
#  'sao filipe',
#  'kruisfontein',
#  'yellowknife',
#  'kavieng',
#  'vao',
#  'clyde river',
#  'dikson',
#  'fairlie',
#  'acapulco',
#  'saint-philippe',
#  'tuatapere',
#  'hoopstad',
#  'ubinskoye',
#  'andros',
#  'hilo',
#  'vila velha',
#  'coos bay',
#  'hamilton',
#  'kwinana',
#  'cizre',
#  'vaini',
#  'kholtoson',
#  'iskateley',
#  'geraldton',
#  'leshukonskoye',
#  'port lincoln',
#  'vanavara',
#  'kodiak',
#  'bambanglipuro',
#  'bubaque',
#  'nouadhibou',
#  'lagoa',
#  'ponta do sol',
#  'east london',
#  'krasnoselkup',
#  'hithadhoo',
#  'buala',
#  'airai',
#  'mayo',
#  'lebu',
#  'tura',
#  'wick',
#  'kerema',
#  'goderich',
#  'pangnirtung',
#  'dalvik',
#  'camana',
#  'mao',
#  'salalah',
#  'hobart',
#  'kamina',
#  'barentu',
#  'oriximina',
#  'nikolskoye',
#  'labuan',
#  'rudbar',
#  'awbari',
#  'kasongo-lunda',
#  'kuching',
#  'nokaneng',
#  'narsaq',
#  'tuktoyaktuk',
#  'sitka',
#  'qasigiannguit',
#  'sebu',
#  'asau',
#  'gimli',
#  'hovd',
#  'chokurdakh',
#  'preobrazheniye',
#  'bolshoy kamen',
#  'cam ranh',
#  'hasaki',
#  'bojnurd',
#  'aquiraz',
#  'phalombe',
#  'lazurne',
#  'muros',
#  'talnakh',
#  'vicksburg',
#  'college',
#  'kurumkan',
#  'kamenka',
#  'te anau',
#  'mar del plata',
#  'pacific grove',
#  'kota belud',
#  'mayumba',
#  'saint-pierre',
#  'la roche-sur-yon',
#  'sibolga',
#  'mayya',
#  'madang',
#  'sile',
#  'mehamn',
#  'pevek',
#  'banyo',
#  'quelimane',
#  'itapecerica',
#  'lata',
#  'rio gallegos',
#  'constitucion',
#  'quang ngai',
#  'homer',
#  'mishan',
#  'omboue',
#  'aksu',
#  'kuytun',
#  'tabuk',
#  'kontagora',
#  'pidhorodne',
#  'butaritari',
#  'ilhabela',
#  'sorland',
#  'cockburn town',
#  'borovoy',
#  'aripuana',
#  'miraflores',
#  'bilma',
#  'port angeles',
#  'klyuchi',
#  'iqaluit',
#  'marawi',
#  'moravske budejovice',
#  'carnarvon',
#  'manakara',
#  'mareeba',
#  'severo-kurilsk',
#  'oistins',
#  'arraial do cabo',
#  'pasighat',
#  'huancavelica',
#  'turan',
#  'lieksa',
#  'anadyr',
#  'grand gaube',
#  'tumpat',
#  'chimbote',
#  'kulpahar',
#  'kirakira',
#  'broome',
#  'adrar',
#  'lang suan',
#  'yerbogachen',
#  'alofi',
#  'fayaoue',
#  'boddam',
#  'tres arroyos',
#  'zolochiv',
#  'zinder',
#  'opuwo',
#  'strenci',
#  'ventspils',
#  'sandnessjoen',
#  'usinsk',
#  'cherskiy',
#  'utete',
#  'inhambane',
#  'severo-yeniseyskiy',
#  'margate',
#  'ust-nera',
#  'aktash',
#  'ormstown',
#  'gaoua',
#  'castro',
#  'iquitos',
#  'almaznyy',
#  'saint george',
#  'totma',
#  'ilulissat',
#  'nizhnyaya tavda',
#  'hami',
#  'praia da vitoria',
#  'sakakah',
#  'russell',
#  'tiksi',
#  'mpanda',
#  'kitimat',
#  'centralia',
#  'broken hill',
#  'roebourne',
#  'sandusky',
#  'sinnamary',
#  'kaeo',
#  'xai-xai',
#  'vanimo',
#  'korostyshiv',
#  'marsaxlokk',
#  'husavik',
#  'waingapu',
#  'leningradskiy',
#  'chuy',
#  'menomonie',
#  'saldanha',
#  'pochutla',
#  'mae sai',
#  'natal',
#  'briancon',
#  'mattru',
#  'klaksvik',
#  'aklavik',
#  'rassvet',
#  'vaitape',
#  'saint-andre-avellin',
#  'zabid',
#  'christchurch',
#  'eenhana',
#  'sinazongwe',
#  'manicore',
#  'meulaboh',
#  'mount isa',
#  'itarema',
#  'katsuura',
#  'yambio',
#  'malaryta',
#  'pudozh',
#  'calbuco',
#  'tibu',
#  'cervo',
#  'fos-sur-mer',
#  'imeni karla libknekhta',
#  'paslek',
#  'bethel',
#  'vila',
#  'periyanegamam',
#  'ibra',
#  'nanortalik',
#  'savannakhet',
#  'skibbereen',
#  'mbuji-mayi',
#  'mogadishu',
#  'hobyo',
#  'zarand',
#  'upernavik',
#  'sagarejo',
#  'komsomolskiy',
#  'evensk',
#  'berbera',
#  'thaba-tseka',
#  'najran',
#  'lumby',
#  'san patricio',
#  'cozumel',
#  'nhulunbuy',
#  'cayenne',
#  'ruteng',
#  'daru',
#  'saucillo',
#  'dingle',
#  'san rafael',
#  'sibu',
#  'pauini',
#  'tingi',
#  'henties bay',
#  'maniitsoq',
#  'karla',
#  'tateyama',
#  'asosa',
#  'maceo',
#  'marzuq',
#  'hambantota',
#  'santa cruz de la palma',
#  'tecoanapa',
#  'helong',
#  'sovetskiy',
#  'livingstone',
#  'chaozhou',
#  'san borja',
#  'faya',
#  'san felipe',
#  'northam',
#  'puerto madryn',
#  'dzerzhinsk',
#  'yaan',
#  'san cristobal',
#  'igarka',
#  'andenes',
#  'belaya gora',
#  'porbandar',
#  'storforshei',
#  'casma',
#  'jinhua',
#  'lastoursville',
#  'jalingo',
#  'jaciara',
#  'lavrentiya',
#  'hurghada',
#  'asahikawa',
#  'grindavik',
#  'makakilo city',
#  'izyaslav',
#  'boulder',
#  'lagos',
#  'port blair',
#  'gamba',
#  'ouesso',
#  'otradnoye',
#  'belmopan',
#  'huilong',
#  'hay river',
#  'necochea',
#  'along',
#  'misratah',
#  'espanola',
#  'santa cruz cabralia',
#  'victor harbor',
#  'gravdal',
#  'gornopravdinsk',
#  'palmer',
#  'puerto suarez',
#  'kahului',
#  'kudat',
#  'hermiston',
#  'tegal',
#  'aldine',
#  'mandalgovi',
#  'bairiki',
#  'karpathos',
#  'teshie',
#  'gobabis',
#  'umm lajj',
#  'monki',
#  'pyapon',
#  'santa fe',
#  'tessalit',
#  'cleveland',
#  'kaithal',
#  'bathsheba',
#  'kieta',
#  'boende',
#  'fresno',
#  'safaga',
#  'zhigalovo',
#  'banjar',
#  'berlevag',
#  'semey',
#  'san bartolome jocotenango',
#  'nuevo progreso',
#  'kalaleh',
#  'kavaratti',
#  'paris',
#  'niltepec',
#  'charleville',
#  'campos belos',
#  'monterey',
#  'toyooka',
#  'santa cruz',
#  'pisco',
#  'bilibino',
#  'egvekinot',
#  'kem',
#  'rabo de peixe',
#  'turukhansk',
#  'svetlogorsk',
#  'vardo',
#  'pangkalanbuun',
#  'damietta',
#  'ahipara',
#  'lahij',
#  'salgado',
#  'soyo',
#  'derzhavinsk',
#  'eydhafushi',
#  'carutapera',
#  'shubarkuduk',
#  'calama',
#  'ussuriysk',
#  'palana',
#  'massakory',
#  'eusebio ayala',
#  'lufkin',
#  'vetluzhskiy',
#  'bafq',
#  'mount gambier',
#  'haines junction',
#  'alamos',
#  'weligama',
#  'isangel',
#  'churapcha',
#  'sao joao da barra',
#  'altay',
#  'melilla',
#  'te kauwhata',
#  'mitrofanovka',
#  'sambava',
#  'kankan',
#  'moose factory',
#  'mamlyutka',
#  'la palma',
#  'ixtapa',
#  'villamontes',
#  'ambon',
#  'dubbo',
#  'seymchan',
#  'ulaangom',
#  'zaraza',
#  'los llanos de aridane',
#  'port moresby',
#  'vostok',
#  'safranbolu',
#  'mumford',
#  'inskoy',
#  'fiumicino',
#  'tukrah',
#  'okhotsk',
#  'zhuhai',
#  'goundam',
#  'alta floresta',
#  'lompoc',
#  'kandrian',
#  'kaili',
#  'kaputa',
#  'guerrero negro',
#  'konispol',
#  'espita',
#  'faanui',
#  'san juan',
#  'acajutla',
#  'yumbe',
#  'koslan',
#  'lasa',
#  'ca mau',
#  'barranquilla',
#  'sola',
#  'nome',
#  'coihaique',
#  'mapastepec',
#  'aleksandrov gay',
#  'havre',
#  'lamu',
#  'kushmurun',
#  'poya',
#  'kupang',
#  'pedernales',
#  'kokoda',
#  'zigong',
#  'lake havasu city',
#  'zomin',
#  'san jeronimo',
#  'zaanstad',
#  'shimoda',
#  'samarai',
#  'abu zabad',
#  'umuahia',
#  'khargone',
#  'kiunga',
#  'aleksandrovka',
#  'auki',
#  'roma',
#  'cordoba',
#  'morondava',
#  'babati',
#  'kiruna',
#  'grove city',
#  'caravelas',
#  'suntar',
#  'verkhoyansk',
#  'florencia',
#  'monze',
#  'kozhva',
#  'empalme',
#  'talaya',
#  'comodoro rivadavia',
#  'hlobyne',
#  'karlskrona',
#  'llanes',
#  'naze',
#  'la seyne-sur-mer',
#  'shache',
#  'itamarandiba',
#  'yarmouth',
#  'burley',
#  'sulangan',
#  'nelson bay',
#  'mazamari',
#  'mataura',
#  'teya',
#  'rosarito',
#  'yulara',
#  'albany',
#  'provideniya',
#  'lewiston',
#  'tual',
#  'diego de almagro',
#  'tazmalt',
#  'praia',
#  'bambous virieux',
#  'rikitea',
#  'kaitangata',
#  'ushuaia',
#  'torbay',
#  'bengkulu',
#  'rudnogorsk',
#  'mandera',
#  'hualmay',
#  'cape town',
#  'shubarshi',
#  'barrow',
#  'ostrovnoy',
#  'the valley',
#  'pocosol',
#  'atuona',
#  'avarua',
#  'mayahi',
#  'touros',
#  'lamar',
#  'ishigaki',
#  'la ronge',
#  'labuhan',
#  'abulug',
#  'ribeira grande',
#  'thompson',
#  'esperance',
#  'shangzhi',
#  'cabo san lucas',
#  'tasiilaq',
#  'qaanaaq',
#  'kapaa',
#  'luderitz',
#  'leon',
#  'linhares',
#  'punta arenas',
#  'puerto ayora',
#  'guider',
#  'norashen',
#  'bluff',
#  'norman wells',
#  'georgetown',
#  'saskylakh',
#  'jamestown',
#  'busselton',
#  'kamenskiy',
#  'pimentel',
#  'cuenca',
#  'honiara',
#  'tautira',
#  'hofn',
#  'saint-francois',
#  'victoria',
#  'batagay-alyta',
#  'cartagena del chaira',
#  'codrington',
#  'bredasdorp',
#  'vila franca do campo',
#  'sabha',
#  'kelo',
#  'pierre',
#  'souillac',
#  'harper',
#  'husainabad',
#  'muravlenko',
#  'beba',
#  'port elizabeth',
#  'atasu',
#  'portland',
#  'new norfolk',
#  'dzhebariki-khaya',
#  'khatanga',
#  'batyrevo',
#  'lorengau',
#  'aljezur',
#  'pachino',
#  'port alfred',
#  'plettenberg bay',
#  'cidreira',
#  'hermanus',
#  'ancud',
#  'kysyl-syr',
#  'longyearbyen',
#  'laguna',
#  'muroto',
#  'mahebourg',
#  'kirkland lake',
#  'alice springs',
#  'sao filipe',
#  'kruisfontein',
#  'yellowknife',
#  'kavieng',
#  'vao',
#  'clyde river',
#  'dikson',
#  'fairlie',
#  'acapulco',
#  'saint-philippe',
#  'tuatapere',
#  'hoopstad',
#  'ubinskoye',
#  'andros',
#  'hilo',
#  'vila velha',
#  'coos bay',
#  'hamilton',
#  'kwinana',
#  'cizre',
#  'vaini',
#  'kholtoson',
#  'iskateley',
#  'geraldton',
#  'leshukonskoye',
#  'port lincoln',
#  'vanavara',
#  'kodiak',
#  'bambanglipuro',
#  'bubaque',
#  'nouadhibou',
#  'lagoa',
#  'ponta do sol',
#  'east london',
#  'krasnoselkup',
#  'hithadhoo',
#  'buala',
#  'airai',
#  'mayo',
#  'lebu',
#  'tura',
#  'wick',
#  'kerema',
#  'goderich',
#  'pangnirtung',
#  'dalvik',
#  'camana',
#  'mao',
#  'salalah',
#  'hobart',
#  'kamina',
#  'barentu',
#  'oriximina',
#  'nikolskoye',
#  'labuan',
#  'rudbar',
#  'awbari',
#  'kasongo-lunda',
#  'kuching',
#  'nokaneng',
#  'narsaq',
#  'tuktoyaktuk',
#  'sitka',
#  'qasigiannguit',
#  'sebu',
#  'asau',
#  'gimli',
#  'hovd',
#  'chokurdakh',
#  'preobrazheniye',
#  'bolshoy kamen',
#  'cam ranh',
#  'hasaki',
#  'bojnurd',
#  'aquiraz',
#  'phalombe',
#  'lazurne',
#  'muros',
#  'talnakh',
#  'vicksburg',
#  'college',
#  'kurumkan',
#  'kamenka',
#  'te anau',
#  'mar del plata',
#  'pacific grove',
#  'kota belud',
#  'mayumba',
#  'saint-pierre',
#  'la roche-sur-yon',
#  'sibolga',
#  'mayya',
#  'madang',
#  'sile',
#  'mehamn',
#  'pevek',
#  'banyo',
#  'quelimane',
#  'itapecerica',
#  'lata',
#  'rio gallegos',
#  'constitucion',
#  'quang ngai',
#  'homer',
#  'mishan',
#  'omboue',
#  'aksu',
#  'kuytun',
#  'tabuk',
#  'kontagora',
#  'pidhorodne',
#  'butaritari',
#  'ilhabela',
#  'sorland',
#  'cockburn town',
#  'borovoy',
#  'aripuana',
#  'miraflores',
#  'bilma',
#  'port angeles',
#  'klyuchi',
#  'iqaluit',
#  'marawi',
#  'moravske budejovice',
#  'carnarvon',
#  'manakara',
#  'mareeba',
#  'severo-kurilsk',
#  'oistins',
#  'arraial do cabo',
#  'pasighat',
#  'huancavelica',
#  'turan',
#  'lieksa',
#  'anadyr',
#  'grand gaube',
#  'tumpat',
#  'chimbote',
#  'kulpahar',
#  'kirakira',
#  'broome',
#  'adrar',
#  'lang suan',
#  'yerbogachen',
#  'alofi',
#  'fayaoue',
#  'boddam',
#  'tres arroyos',
#  'zolochiv',
#  'zinder',
#  'opuwo',
#  'strenci',
#  'ventspils',
#  'sandnessjoen',
#  'usinsk',
#  'cherskiy',
#  'utete',
#  'inhambane',
#  'severo-yeniseyskiy',
#  'margate',
#  'ust-nera',
#  'aktash',
#  'ormstown',
#  'gaoua',
#  'castro',
#  'iquitos',
#  'almaznyy',
#  'saint george',
#  'totma',
#  'ilulissat',
#  'nizhnyaya tavda',
#  'hami',
#  'praia da vitoria',
#  'sakakah',
#  'russell',
#  'tiksi',
#  'mpanda',
#  'kitimat',
#  'centralia',
#  'broken hill',
#  'roebourne',
#  'sandusky',
#  'sinnamary',
#  'kaeo',
#  'xai-xai',
#  'vanimo',
#  'korostyshiv',
#  'marsaxlokk',
#  'husavik',
#  'waingapu',
#  'leningradskiy',
#  'chuy',
#  'menomonie',
#  'saldanha',
#  'pochutla',
#  'mae sai',
#  'natal',
#  'briancon',
#  'mattru',
#  'klaksvik',
#  'aklavik',
#  'rassvet',
#  'vaitape',
#  'saint-andre-avellin',
#  'zabid',
#  'christchurch',
#  'eenhana',
#  'sinazongwe',
#  'manicore',
#  'meulaboh',
#  'mount isa',
#  'itarema',
#  'katsuura',
#  'yambio',
#  'malaryta',
#  'pudozh',
#  'calbuco',
#  'tibu',
#  'cervo',
#  'fos-sur-mer',
#  'imeni karla libknekhta',
#  'paslek',
#  'bethel',
#  'vila',
#  'periyanegamam',
#  'ibra',
#  'nanortalik',
#  'savannakhet',
#  'skibbereen',
#  'mbuji-mayi',
#  'mogadishu',
#  'hobyo',
#  'zarand',
#  'upernavik',
#  'sagarejo',
#  'komsomolskiy',
#  'evensk',
#  'berbera',
#  'thaba-tseka',
#  'najran',
#  'lumby',
#  'san patricio',
#  'cozumel',
#  'nhulunbuy',
#  'cayenne',
#  'ruteng',
#  'daru',
#  'saucillo',
#  'dingle',
#  'san rafael',
#  'sibu',
#  'pauini',
#  'tingi',
#  'henties bay',
#  'maniitsoq',
#  'karla',
#  'tateyama',
#  'asosa',
#  'maceo',
#  'marzuq',
#  'hambantota',
#  'santa cruz de la palma',
#  'tecoanapa',
#  'helong',
#  'sovetskiy',
#  'livingstone',
#  'chaozhou',
#  'san borja',
#  'faya',
#  'san felipe',
#  'northam',
#  'puerto madryn',
#  'dzerzhinsk',
#  'yaan',
#  'san cristobal',
#  'igarka',
#  'andenes',
#  'belaya gora',
#  'porbandar',
#  'storforshei',
#  'casma',
#  'jinhua',
#  'lastoursville',
#  'jalingo',
#  'jaciara',
#  'lavrentiya',
#  'hurghada',
#  'asahikawa',
#  'grindavik',
#  'makakilo city',
#  'izyaslav',
#  'boulder',
#  'lagos',
#  'port blair',
#  'gamba',
#  'ouesso',
#  'otradnoye',
#  'belmopan',
#  'huilong',
#  'hay river',
#  'necochea',
#  'along',
#  'misratah',
#  'espanola',
#  'santa cruz cabralia',
#  'victor harbor',
#  'gravdal',
#  'gornopravdinsk',
#  'palmer',
#  'puerto suarez',
#  'kahului',
#  'kudat',
#  'hermiston',
#  'tegal',
#  'aldine',
#  'mandalgovi',
#  'bairiki',
#  'karpathos',
#  'teshie',
#  'gobabis',
#  'umm lajj',
#  'monki',
#  'pyapon',
#  'santa fe',
#  ...]

# %%
requests.get(query_url + city).json()
# Out:
# {'coord': {'lon': -113.7928, 'lat': 42.5357},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 6.97,
#   'feels_like': 5.61,
#   'temp_min': 4.95,
#   'temp_max': 8.69,
#   'pressure': 1026,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 180},
#  'clouds': {'all': 1},
#  'dt': 1635908953,
#  'sys': {'type': 1,
#   'id': 3536,
#   'country': 'US',
#   'sunrise': 1635862226,
#   'sunset': 1635899216},
#  'timezone': -21600,
#  'id': 5587385,
#  'name': 'Burley',
#  'cod': 200}

# %%
#Dataframe

weather_df = pd.DataFrame({"cities": new_cities,
              "cloudiness": cloudiness,
              "humidity":humidity,
              "Temp": temperature,
              "lat": lat,
              "long":lng,
              "windy speed":wind_speedy 
})
weather_df
# Out:
#                cities  cloudiness  humidity   Temp      lat      long  \
# 0            sulangan         100        82  26.30  11.1373  123.7228
# 1          nelson bay         100        52  26.83 -32.7167  152.1500
# 2            mazamari          62        92  20.96 -11.3258  -74.5308
# 3             mataura           0        33  15.27 -46.1927  168.8643
# 4                teya         100        85 -14.85  60.3778   92.6267
# ..                ...         ...       ...    ...      ...       ...
# 569  la seyne-sur-mer          85        89  16.98  43.0982    5.8847
# 570            shache           0        26   8.94  38.4167   77.2406
# 571      itamarandiba          66        97  17.50 -17.8572  -42.8589
# 572          yarmouth          90        93   9.43  41.7057  -70.2286
# 573            burley           1        81   8.69  42.5357 -113.7928
#
#      windy speed
# 0           9.35
# 1           2.24
# 2           1.53
# 3           3.50
# 4           2.27
# ..           ...
# 569         0.45
# 570         1.27
# 571         1.08
# 572         1.54
# 573         2.06
#
# [574 rows x 7 columns]

# %%
weather_df.head()
# Out:
#        cities  cloudiness  humidity   Temp      lat      long  windy speed
# 0    sulangan         100        82  26.30  11.1373  123.7228         9.35
# 1  nelson bay         100        52  26.83 -32.7167  152.1500         2.24
# 2    mazamari          62        92  20.96 -11.3258  -74.5308         1.53
# 3     mataura           0        33  15.27 -46.1927  168.8643         3.50
# 4        teya         100        85 -14.85  60.3778   92.6267         2.27

# %%
len(new_cities)
# Out:
# 574

# %%
len(lat)
# Out:
# 574

# %%
len(humidity)
# Out:
# 574

# %%
# #run linear regression on each relationship, only this time separating them into Northern Hemisphere 
# (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)

# %%
temperature
# Out:
# [26.3,
#  26.83,
#  20.96,
#  15.27,
#  -14.85,
#  16.63,
#  29.88,
#  4.06,
#  -2.94,
#  8.46,
#  29.05,
#  16.03,
#  18.56,
#  25.82,
#  24.01,
#  23.1,
#  11.7,
#  8.91,
#  5.49,
#  26.3,
#  -9.26,
#  25.17,
#  17.92,
#  14.04,
#  -0.48,
#  -8.99,
#  2.23,
#  26.92,
#  23.78,
#  25.52,
#  26.03,
#  26.33,
#  26.5,
#  9.64,
#  24.27,
#  -0.73,
#  30.54,
#  28.17,
#  20.91,
#  -4.39,
#  19.44,
#  6.96,
#  26.95,
#  1.09,
#  -14.17,
#  24.15,
#  12.65,
#  15.68,
#  21.87,
#  10.06,
#  21.07,
#  25.26,
#  11.74,
#  15.45,
#  -8.98,
#  28.96,
#  -15.13,
#  2.51,
#  17.71,
#  4.63,
#  16.99,
#  12.73,
#  28.08,
#  28.01,
#  -1.4,
#  9.26,
#  28.31,
#  -16.94,
#  22.56,
#  17.2,
#  8.49,
#  21.78,
#  21.65,
#  24.41,
#  0.71,
#  24.09,
#  25.17,
#  22.02,
#  -17.11,
#  21.35,
#  12.89,
#  -9.91,
#  12.46,
#  22.72,
#  -3.71,
#  -20.55,
#  4.9,
#  29.54,
#  15.89,
#  18.74,
#  14.69,
#  12.43,
#  20.44,
#  13.83,
#  12.4,
#  -12.82,
#  -6.09,
#  17.91,
#  18.66,
#  24.03,
#  -1.88,
#  26.75,
#  26.82,
#  10.21,
#  -0.8,
#  28.89,
#  21.07,
#  -5.4,
#  -9.88,
#  7.78,
#  26.11,
#  23.45,
#  15.46,
#  13.74,
#  -15.29,
#  19.31,
#  25.69,
#  22.52,
#  14.4,
#  3.74,
#  21.86,
#  -6.48,
#  24,
#  -9.76,
#  15.28,
#  9.45,
#  5.25,
#  10.71,
#  20.61,
#  16.98,
#  8.94,
#  17.5,
#  9.43,
#  8.69]

# %%
#A max temperature lower than 80 degrees but higher than 70

# weather_df.loc[(weather_df["Temp"] > 80) & (weather_df["Temp"] < 70)]

df_temp = weather_df.loc[weather_df["Temp"]>80 & (weather_df["Temp"] < 70)]
df_temp
# Out:
#                cities  cloudiness  humidity   Temp      lat      long  \
# 0            sulangan         100        82  26.30  11.1373  123.7228
# 1          nelson bay         100        52  26.83 -32.7167  152.1500
# 2            mazamari          62        92  20.96 -11.3258  -74.5308
# 3             mataura           0        33  15.27 -46.1927  168.8643
# 5            rosarito          31        83  16.63  32.3333 -117.0333
# ..                ...         ...       ...    ...      ...       ...
# 569  la seyne-sur-mer          85        89  16.98  43.0982    5.8847
# 570            shache           0        26   8.94  38.4167   77.2406
# 571      itamarandiba          66        97  17.50 -17.8572  -42.8589
# 572          yarmouth          90        93   9.43  41.7057  -70.2286
# 573            burley           1        81   8.69  42.5357 -113.7928
#
#      windy spped
# 0           9.35
# 1           2.24
# 2           1.53
# 3           3.50
# 5           3.57
# ..           ...
# 569         0.45
# 570         1.27
# 571         1.08
# 572         1.54
# 573         2.06
#
# [489 rows x 7 columns]

# %%
df_temp.sort_values
# Out:
# <bound method DataFrame.sort_values of                cities  cloudiness  humidity   Temp      lat      long  \
# 0            sulangan         100        82  26.30  11.1373  123.7228
# 1          nelson bay         100        52  26.83 -32.7167  152.1500
# 2            mazamari          62        92  20.96 -11.3258  -74.5308
# 3             mataura           0        33  15.27 -46.1927  168.8643
# 5            rosarito          31        83  16.63  32.3333 -117.0333
# ..                ...         ...       ...    ...      ...       ...
# 569  la seyne-sur-mer          85        89  16.98  43.0982    5.8847
# 570            shache           0        26   8.94  38.4167   77.2406
# 571      itamarandiba          66        97  17.50 -17.8572  -42.8589
# 572          yarmouth          90        93   9.43  41.7057  -70.2286
# 573            burley           1        81   8.69  42.5357 -113.7928
#
#      windy spped
# 0           9.35
# 1           2.24
# 2           1.53
# 3           3.50
# 5           3.57
# ..           ...
# 569         0.45
# 570         1.27
# 571         1.08
# 572         1.54
# 573         2.06
#
# [489 rows x 7 columns]>

# %%
#Temperature (F) vs. Latitude

plt.scatter(weather_df["lat"], weather_df["Temp"], color = "green", edgecolor = "black")

plt.title("Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Picture1.png")

# %%
#Humidity (%) vs. Latitude

plt.scatter(weather_df["lat"], weather_df["humidity"], color = "green", edgecolor = "black")

plt.title("Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Humidity x Lat.png")

# %%
#Cloudiness (%) vs. Latitude

plt.scatter(weather_df["lat"], weather_df["cloudiness"], color = "green", edgecolor = "black")

plt.title("Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Claudiness x Lat.png")

# %%
#Wind Speed (mph) vs. Latitude

plt.scatter(weather_df["lat"], weather_df["windy speed"], color = "green", edgecolor = "black")

plt.title("Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind_speedy (mph)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.savefig("Wind_speedy x Lat.png")
